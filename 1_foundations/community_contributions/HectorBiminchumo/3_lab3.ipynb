# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
import os
load_dotenv(override=True)
openai = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contactar
# hectorbiminchumo@gmail.com
# www.linkedin.com/in/
# hectorbiminchumo (LinkedIn)
# Aptitudes principales
# Agentic Workflows
# Generative AI for Software
# Engineering
# SOLID Design Principles
# Languages
# Inglés (Full Professional)
# Certifications
# React -The Complete Guide
# 2023(incl. ReactRouter& Redux)
# React Query: Server State
# Management in React
# React Testing Library with Jest/Vitest
# AWS Lambda & Serverless
# Architecture Bootcamp
# Certificado Verificado de edX para el
# curso Analyzing and Visualizing Data
# with Excel
# Héctor Biminchumo
# Senior Full Stack Engineer | Agentic Coding Specialist | AWS
# Serverless | Node.js | ReactJS, Next.js | TypeScript
# Perú
# Extracto
# I’m Héctor, a Senior Full Stack Engineer with 4+ years of experience
# building mission-critical web applications for the North American
# and Latin American markets. I specialize in Agentic Coding,
# leveraging autonomous AI environments (Claude Code, Cursor)
# to accelerate development cycles by 90% while maintaining
# the highest engineering standards.My approach combines a
# systems-thinking mindset—rooted in my Industrial Engineering
# background—with deep expertise in the MERN stack and AWS
# Serverless architecture. I don't just write code; I architect intelligent,
# scalable solutions that solve complex business logic.Key Technical
# Milestones:Performance: Reduced AWS Lambda execution time
# by 70% and improved frontend load times by 30% through strategic
# refactoring and memory optimization.Architecture: Accelerated
# deployment cycles by 40% by implementing Micro-frontend
# architectures and decoupled backend services.Data &amp; Ops:
# Experienced in modernizing legacy systems and designing robust
# data pipelines using AWS (Step Functions, Glue) and Dagster.My
# Technical Ecosystem:Languages &amp; Frameworks: JavaScript
# (ES6+), TypeScript, Node.js, NestJS, and Django (Python).Frontend
# Mastery: React.js, Next.js, Micro-frontends, Tailwind CSS.Cloud
# &amp; Infrastructure: AWS Specialist (Lambda, SQS, DynamoDB,
# CloudWatch), Cloudflare, and Serverless Frameworks.Agentic Tools:
# Expert-level proficiency in Claude Code and Agentic Workflows for
# autonomous debugging and refactoring.Engineering Excellence:
# Clean Code, SOLID principles, and Test-Driven Development
# (TDD).I thrive in international, cross-functional teams where I can
# turn ambiguous requirements into well-structured engineering plans.
# Currently, I am focused on the intersection of AI-driven development
# and Fintech/Retail digital transformation.When I’m not orchestrando
# agentic workflows or optimizing cloud infrastructure, you'll find
# me dancing salsa or hitting the gym. I believe in maintaining peak
# performance—both in code architecture and in life.Let’s connect if
#   Page 1 of 4
# you’re looking for a disciplined, high-impact engineer to build the
# next generation of intelligent software!
# Experiencia
# Baufest
# Full Stack Developer
# febrero de 2022 - marzo de 2026 (4 años 2 meses)
# Lima, Perú
# Les Schwab Project | September 2024 - March 2026
# - Dispatch modernizes legacy iSeries sales audit processes by migrating
# to AWS, ensuring all POS invoices and related transactions are validated,
# corrected, and enriched for downstream systems.
# - Analyzed business and technical requirements to build the application in
# alignment with strict test-driven development (TDD).
# - Reduced Lambda execution time by 70% through native Date API adoption
# (19x faster), memory preallocation (60% reduction), and p95/p99 performance
# testing framework.
# Les Schwab Project | March 2024 - August 2024
# - Implemented bug fixes and functionality enhancement by using react
# libraries, this helped us to implement automatic logout for idle users, which
# also improved security and a 30% increase in user satisfaction scores,
# measured over a two-month period.
# - Implemented unit tests and increased test coverage from 0% to 45%,
# resulting in a 40% reduction in production bugs and improvement in code
# reliability.
# Cencosud Project | February 2022 - January 2024
# - Successfully implemented Micro-frontend architecture, resulting in a 40%
# reduction in deployment times and a 25% increase in development team
# productivity through improved modularity and parallel development.
# - Optimized data fetching strategy by minimizing the use of the useEffect
# hook, resulting in a 30% reduction in load time and improved application
# performance.
# - Introduced and enforced best practices for code quality and version control,
# resulting in a 40% reduction in codebase-related issues and improvement in
# overall maintainability and scalability.
#   Page 2 of 4
# - Successfully integrated 30 to 40 frontend components with 30 to 40 backend
# APIs, ensuring seamless data flow and enhancing the overall functionality of
# the application.
# Grupo Socopur
# Demand Planner
# agosto de 2018 - julio de 2020 (2 años)
# Distrito de Ate, Departamento de Lima, Peru
# Planning spare parts import, managed a $300K USD inventory, daily
# communication with customers and continuous trained to warehouse team.
# Achievements:
# - Increased sales by 500% through optimizing spare parts planning and
# enhancing regional distribution analysis.
# - Reduced import goods checking time in the warehouse by 50% by
# developing comprehensive catalogs and implementing a new coding system.
# - Led a team of 4 in inventory management, reducing physical inventory errors
# by 90% through meticulous checks and process improvements.
# Scania del Peru S.A.
# Finance and Administrative Assistant
# 2016 - 2018 (2 años)
# Lima, Perú
# Monitored accounts payables transactions and allocating funds to cash on all
# national branches, bought and sold foreign currency.
# Achievements:
# - Spearheaded the transition to a paperless practice by implementing an
# electronic booking system, cutting paper use by 80%.
# - Automated repetitive tasks using Excel Macros/VBA, saving over 10 hours of
# analysis time per week.
# - Standardized financial reports across all national branches by leading a 6-
# member team, ensuring consistency and accuracy.
# Automotores Gildemeister SA
# Planning Analyst
# 2015 - 2016 (1 año)
# Lima, Perú
# Empresas Indumotora
#   Page 3 of 4
# Planning Analyst
# 2014 - 2015 (1 año)
# Lima, Perú
# Derco
# Planning Trainee
# 2012 - 2014 (2 años)
# Educación
# Ironhack
# Full-Stack Web Developer Program - IronHack Bootcamp, Information
# Technology · (octubre de 2021 - diciembre de 2021)
# Universidad  ESAN
# Major in Corporate Finance  · (2018 - 2019)
# Universidad ESAN
# Major in Logistic and Operations  · (2015 - 2016)
# Universidad Nacional Federico Villarreal
# Bachelor of Engineering (B.E.), Industrial Engineering · (2009 - 2013)
# Universidad Nacional Mayor de San Marcos
#  · (2013 - 2013)
#   Page 4 of 4

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Hector Biminchumo"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Hector Biminchumo. You are answering questions on Hector Biminchumo's website, particularly questions related to Hector Biminchumo's career, background, skills and experience. Your responsibility is to represent Hector Biminchumo for interactions on the website as faithfully as possible. You are given a summary of Hector Biminchumo's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Hector Biminchumo. I'm an software engineer and industrial engineer. I'm originally from Lima, Peru.\nI love doing exercise and dancing salsa, particularly Cuban salsa. I go to the gym at least 4 times per week.\nI really travel, three years ago I was in Colombia, visiting Cartagena where is really hot, the beach was awesome but I didn't enjoy the weather it was really hot, then I was in Medellin, I love it! the weather and people treatment are great, I would love to live there. Also Medellin is considered the Silicon Valley of latin america.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContactar\nhectorbiminchumo@gmail.com\nwww.linkedin.com/in/\nhectorbiminchumo (LinkedIn)\nAptitudes principales\nAgentic Workflows\nGenerative AI for Software\nEngineering\nSOLID Design Principles\nLanguages\nInglés (Full Professional)\nCertifications\nReact -The Complete Guide\n2023(incl. ReactRouter& Redux)\nReact Query: Server State\nManagement in React\nReact Testing Library with Jest/Vitest\nAWS Lambda & Serverless\nArchitecture Bootcamp\nCertificado Verificado de edX para el\ncurso Analyzing and Visualizing Data\nwith Excel\nHéctor Biminchumo\nSenior Full Stack Engineer | Agentic Coding Specialist | AWS\nServerless | Node.js | ReactJS, Next.js | TypeScript\nPerú\nExtracto\nI’m Héctor, a Senior Full Stack Engineer with 4+ years of experience\nbuilding mission-critical web applications for the North American\nand Latin American markets. I specialize in Agentic Coding,\nleveraging autonomous AI environments (Claude Code, Cursor)\nto accelerate development cycles by 90% while maintaining\nthe highest engineering standards.My approach combines a\nsystems-thinking mindset—rooted in my Industrial Engineering\nbackground—with deep expertise in the MERN stack and AWS\nServerless architecture. I don't just write code; I architect intelligent,\nscalable solutions that solve complex business logic.Key Technical\nMilestones:Performance: Reduced AWS Lambda execution time\nby 70% and improved frontend load times by 30% through strategic\nrefactoring and memory optimization.Architecture: Accelerated\ndeployment cycles by 40% by implementing Micro-frontend\narchitectures and decoupled backend services.Data &amp; Ops:\nExperienced in modernizing legacy systems and designing robust\ndata pipelines using AWS (Step Functions, Glue) and Dagster.My\nTechnical Ecosystem:Languages &amp; Frameworks: JavaScript\n(ES6+), TypeScript, Node.js, NestJS, and Django (Python).Frontend\nMastery: React.js, Next.js, Micro-frontends, Tailwind CSS.Cloud\n&amp; Infrastructure: AWS Specialist (Lambda, SQS, DynamoDB,\nCloudWatch), Cloudflare, and Serverless Frameworks.Agentic Tools:\nExpert-level proficiency in Claude Code and Agentic Workflows for\nautonomous debugging and refactoring.Engineering Excellence:\nClean Code, SOLID principles, and Test-Driven Development\n(TDD).I thrive in international, cross-functional teams where I can\nturn ambiguous requirements into well-structured engineering plans.\nCurrently, I am focused on the intersection of AI-driven development\nand Fintech/Retail digital transformation.When I’m not orchestrando\nagentic workflows or optimizing cloud infrastructure, you'll find\nme dancing salsa or hitting the gym. I believe in maintaining peak\nperformance—both in code architecture and in life.Let’s connect if\n\xa0 Page 1 of 4\xa0 \xa0\nyou’re looking for a discipline ...

# %%
def chat(message, history):
    
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gemini-2.5-flash-lite", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash-lite", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gemini-2.5-flash-lite", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# "That's a great question! As of right now, I don't hold any patents. My focus has primarily been on applying cutting-edge technologies and engineering principles to build robust and scalable software solutions. I'm more about the practical implementation and bringing innovative ideas to life through code and system design.\n\nIf you're interested in my technical background or how I approach problem-solving, I'd be happy to share more details about my experience in areas like Agentic Workflows, Generative AI for Software Engineering, and AWS Serverless architecture."

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The response directly answers the user's question and offers further engagement by suggesting topics relevant to Hector's expertise. It maintains a professional and engaging tone, consistent with the persona.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gemini-2.5-flash-lite", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gemini-2.5-flash-lite", messages=messages)
    reply = response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Passed evaluation - returning reply
