# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
# openai_api_key = os.getenv('OPENAI_API_KEY')
openai_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins AIzaSyDy

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv('GOOGLE_API_KEY')
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = gemini.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = gemini.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If a logician, a mathematician, and a physicist are each given a set of twelve identical-looking coins, and they are told that exactly one coin is counterfeit and weighs either slightly more or slightly less than the genuine coins, how can each of them, using only a balance scale and performing a maximum of three weighings, guarantee they can identify the counterfeit coin and determine if it's heavier or lighter?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = gemini.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# This is a classic riddle that highlights the different problem-solving approaches of each discipline. Here's how each of them can solve it:
#
# ## The Setup:
#
# *   **12 identical-looking coins.**
# *   **1 counterfeit coin.**
# *   **The counterfeit is either slightly heavier (H) or slightly lighter (L) than the genuine coins.**
# *   **A balance scale.**
# *   **Maximum of 3 weighings.**
#
# ## The Core Principle:
#
# The balance scale has three possible outcomes for each weighing:
#
# 1.  **Left side is heavier.**
# 2.  **Right side is heavier.**
# 3.  **Both sides are equal.**
#
# With three weighings, we have $3 \times 3 \times 3 = 27$ possible outcomes. We need to identify one of 12 coins as counterfeit AND its nature (heavier or lighter), which means $12 \times 2 = 24$ possibilities. Since 27 > 24, it is theoretically possible.
#
# ## The Solutions:
#
# ### 1. The Logician's Approach: Deductive Reasoning and Exhaustive Cases
#
# The logician will approach this by systematically eliminating possibilities through carefully chosen weighings. They don't rely on "intuition" about physics but on the logical implications of each outcome.
#
# **Labeling:** Number the coins from 1 to 12.
#
# **Weighing 1:**
# *   **Group A:** Coins 1, 2, 3, 4
# *   **Group B:** Coins 5, 6, 7, 8
# *   **On the scale:** Put Group A on the left side, Group B on the right side.
#
#     *   **Outcome 1: The scale balances.**
#         *   This means coins 1-8 are all genuine.
#         *   The counterfeit coin must be among coins 9, 10, 11, 12.
#         *   We now need to determine which of these 4 is counterfeit and if it's heavy or light. We have 2 weighings left.
#
#     *   **Outcome 2: The left side is heavier (A > B).**
#         *   This means the counterfeit coin is either one of the coins in Group A (1, 2, 3, 4) and is *heavier*, OR it's one of the coins in Group B (5, 6, 7, 8) and is *lighter*.
#         *   Coins 9-12 are genuine.
#         *   We have 8 potential counterfeit coins (4 potentially heavy, 4 potentially light). We have 2 weighings left.
#
#     *   **Outcome 3: The right side is heavier (B > A).**
#         *   This is symmetrical to Outcome 2. The counterfeit coin is either one of the coins in Group A (1, 2, 3, 4) and is *lighter*, OR it's one of the coins in Group B (5, 6, 7, 8) and is *heavier*.
#         *   Coins 9-12 are genuine.
#         *   We have 8 potential counterfeit coins (4 potentially light, 4 potentially heavy). We have 2 weighings left.
#
# **Detailed Breakdown of Subsequent Weighings (Logician):**
#
# Let's follow **Outcome 1 (Scale balances in Weighing 1):**
# *   Counterfeit is among {9, 10, 11, 12}. We need to find which and its nature.
# *   **Weighing 2:**
#     *   **Group C:** Coins 9, 10
#     *   **Group D:** Coin 11, and one known genuine coin (e.g., coin 1)
#     *   **On the scale:** Put Group C on the left, Group D on the right.
#
#         *   **Outcome 1a (Scale balances):** Coins 9, 10, 11 are genuine. The counterfeit must be coin 12.
#             *   **Weighing 3:** Weigh coin 12 against a known genuine coin. If 12 is heavier, it's heavier. If 12 is lighter, it's lighter.
#         *   **Outcome 1b (Left side is heavier):** Either coin 9 is heavy, or coin 10 is heavy. Coin 11 is genuine.
#             *   **Weighing 3:** Weigh coin 9 against coin 10. If 9 is heavier, it's the heavy counterfeit. If 10 is heavier, it's the heavy counterfeit. (This is a slight simplification; a more rigorous logician would also consider the case where coin 11 might be lighter, but the grouping is designed to avoid this ambiguity.) Let's refine this:
#             *   **Correct Weighing 3 for Outcome 1b:** Weigh coin 9 against a known genuine coin (e.g., coin 1).
#                 *   If 9 is heavier: Coin 9 is the heavy counterfeit.
#                 *   If 9 balances: Coin 10 must be the heavy counterfeit (since it's the only other possibility from the "left heavier" outcome).
#         *   **Outcome 1c (Right side is heavier):** This is trickier. It implies either coin 9 is lighter, or coin 10 is lighter, OR coin 11 is heavier.
#             *   **Weighing 3:** Weigh coin 9 against coin 10.
#                 *   If 9 is lighter: Coin 9 is the light counterfeit.
#                 *   If 10 is lighter: Coin 10 is the light counterfeit.
#                 *   If they balance: Coin 11 must be the heavy counterfeit.
#
# Let's follow **Outcome 2 (Left side is heavier in Weighing 1: 1,2,3,4 > 5,6,7,8):**
# *   Potential counterfeits: {1H, 2H, 3H, 4H, 5L, 6L, 7L, 8L}. Known genuine: {9, 10, 11, 12}.
# *   **Weighing 2:**
#     *   **Group C:** Coins 1, 2, 5 (potential heavy, potential heavy, potential light)
#     *   **Group D:** Coins 3, 6, 9 (potential heavy, potential light, known genuine)
#     *   **On the scale:** Put Group C on the left, Group D on the right.
#
#         *   **Outcome 2a (Scale balances):** The counterfeit is not in C or D. It must be among the remaining possibilities from the first weighing that weren't used. These are coin 4 (potentially heavy) and coins 7 or 8 (potentially light).
#             *   **Weighing 3:** Weigh coin 4 against a known genuine coin (e.g., coin 9).
#                 *   If 4 is heavier: Coin 4 is the heavy counterfeit.
#                 *   If 4 balances: The counterfeit must be among 7 or 8 and be lighter. Weigh coin 7 against coin 8. The lighter one is the counterfeit.
#         *   **Outcome 2b (Left side is heavier):** This means the heavier coin is on the left, and the lighter coin is on the right, *relative to the possibilities of this weighing*.
#             *   Possible heavy coins on the left side: {1H, 2H}.
#             *   Possible light coins on the right side: {6L}.
#             *   So, the counterfeit is either 1H, 2H, or 6L.
#             *   **Weighing 3:** Weigh coin 1 against coin 2.
#                 *   If 1 is heavier: Coin 1 is the heavy counterfeit.
#                 *   If 2 is heavier: Coin 2 is the heavy counterfeit.
#                 *   If they balance: Coin 6 must be the light counterfeit.
#         *   **Outcome 2c (Right side is heavier):** This means the lighter coin is on the left, and the heavier coin is on the right, *relative to the possibilities of this weighing*.
#             *   Possible light coins on the left side: {5L}.
#             *   Possible heavy coins on the right side: {3H}.
#             *   So, the counterfeit is either 5L or 3H.
#             *   **Weighing 3:** Weigh coin 3 against a known genuine coin (e.g., coin 9).
#                 *   If 3 is heavier: Coin 3 is the heavy counterfeit.
#                 *   If 3 balances: Coin 5 must be the light counterfeit.
#
# The logician's process is exhaustive, meticulously tracing every logical branch.
#
# ---
#
# ### 2. The Mathematician's Approach: Information Theory and Binary Representation
#
# The mathematician sees this as an information-theoretic problem. Each weighing provides a piece of information, and they want to maximize the information gained in each step to distinguish between the 24 possibilities. They often use a numbering system that aligns with the outcomes.
#
# **Labeling:** Assign a unique "state" to each coin based on its potential to be heavy or light.
#
# *   For coins 1-11: We can represent their potential states with a 3-digit ternary number (base 3) for each weighing, where:
#     *   `+1` means the coin is on the left side and potentially heavy.
#     *   `-1` means the coin is on the right side and potentially light.
#     *   `0` means the coin is not weighed and is potentially genuine or its status is unknown from this weighing.
#
# This is a bit complex to illustrate without a detailed table, but the core idea is to design weighings such that the outcome of the three weighings uniquely maps to one of the 24 possibilities.
#
# **A common mathematical strategy uses ternary (base-3) encoding for the coin states:**
#
# *   Assign numbers 1 to 12 to the coins.
# *   Represent each weighing as a vector of length 12, where each element indicates:
#     *   `1`: Coin is on the left pan.
#     *   `-1`: Coin is on the right pan.
#     *   `0`: Coin is off the scale.
#
# Let the three weighings be represented by vectors $W_1, W_2, W_3$. The outcome of the three weighings can be represented by a vector $O = (o_1, o_2, o_3)$, where $o_i$ is the result of the $i$-th weighing:
# *   `1`: Left pan heavier
# *   `-1`: Right pan heavier
# *   `0`: Pans are equal
#
# The key is that the sum of the weighted coin values must equal the outcome. If coin $j$ is counterfeit and heavier, it contributes $1$ to the sum. If it's counterfeit and lighter, it contributes $-1$.
#
# The mathematician will design $W_1, W_2, W_3$ such that the product $W_i \cdot C$ (where $C$ is the vector of coin values) maps to the outcome vector $O$, and this mapping is unique for all 24 possibilities.
#
# **Simplified Mathematical Insight:**
# The mathematician understands that each weighing divides the problem space.
# *   **Weighing 1:** Divides the 24 possibilities into three roughly equal groups (e.g., about 8 possibilities if the scale tips, or more if it balances, depending on the setup).
# *   **Weighing 2:** Divides each of those groups into three smaller groups.
# *   **Weighing 3:** Divides those even smaller groups into three final outcomes, allowing pinpointing.
#
# The mathematician's advantage is in finding the *optimal* weighing strategy that maximizes the information gained at each step, ensuring no possibility is overlooked and all outcomes are distinct. They might use a system of assigning weights to coins based on their potential status and the weighing pans.
#
# ---
#
# ### 3. The Physicist's Approach: Observation and Physical Properties
#
# The physicist will leverage their understanding of physical properties and how they manifest. They're less about pure logic or abstract information theory and more about how the physical world behaves. They'll likely focus on patterns and deviations.
#
# **Labeling:** Coins 1-12.
#
# **Weighing 1:**
# *   **Group A:** Coins 1, 2, 3, 4
# *   **Group B:** Coins 5, 6, 7, 8
# *   **On the scale:** Put Group A on the left, Group B on the right.
#
#     *   **Outcome 1: The scale balances.**
#         *   The physicist observes that coins 1-8 have the same weight. This is empirical evidence they are genuine.
#         *   The counterfeit is among 9, 10, 11, 12.
#         *   They now have a set of known genuine coins to use as references.
#
#     *   **Outcome 2: The left side is heavier.**
#         *   The physicist thinks: "Okay, either one of the coins on the left is heavy, or one of the coins on the right is light. The coins not weighed (9-12) are definitely genuine." They are focusing on the *physical reality* of the imbalance.
#
#     *   **Outcome 3: The right side is heavier.**
#         *   Symmetrical to Outcome 2.
#
# **Detailed Breakdown of Subsequent Weighings (Physicist):**
#
# Let's follow **Outcome 1 (Scale balances in Weighing 1):**
# *   Counterfeit is among {9, 10, 11, 12}. We have genuine coins (e.g., 1-8).
# *   **Weighing 2:**
#     *   **Group C:** Coins 9, 10, 11
#     *   **Group D:** Three known genuine coins (e.g., 1, 2, 3)
#     *   **On the scale:** Put Group C on the left, Group D on the right.
#
#         *   **Outcome 1a (Scale balances):** Coins 9, 10, 11 are genuine. The counterfeit must be coin 12.
#             *   **Weighing 3:** Weigh coin 12 against a genuine coin (e.g., coin 1). Observe if 12 is heavier or lighter.
#         *   **Outcome 1b (Left side is heavier):** The imbalance tells the physicist that one of the coins 9, 10, 11 is heavier than a genuine coin.
#             *   **Weighing 3:** Weigh coin 9 against coin 10.
#                 *   If 9 is heavier: 9 is the heavy counterfeit.
#                 *   If 10 is heavier: 10 is the heavy counterfeit.
#                 *   If they balance: Coin 11 must be the heavy counterfeit.
#         *   **Outcome 1c (Right side is heavier):** The imbalance tells the physicist that one of the coins 9, 10, 11 is lighter than a genuine coin.
#             *   **Weighing 3:** Weigh coin 9 against coin 10.
#                 *   If 9 is lighter: 9 is the light counterfeit.
#                 *   If 10 is lighter: 10 is the light counterfeit.
#                 *   If they balance: Coin 11 must be the light counterfeit.
#
# Let's follow **Outcome 2 (Left side is heavier in Weighing 1: 1,2,3,4 > 5,6,7,8):**
# *   Potential counterfeits: {1H, 2H, 3H, 4H, 5L, 6L, 7L, 8L}. Known genuine: {9, 10, 11, 12}.
# *   **Weighing 2:**
#     *   **Group C:** Coins 1, 2, 5 (potential heavy, potential heavy, potential light)
#     *   **Group D:** Coins 3, 6, 9 (potential heavy, potential light, known genuine)
#     *   **On the scale:** Put Group C on the left, Group D on the right.
#
#         *   **Outcome 2a (Scale balances):** The physicist notes the balance. The counterfeit must be among the coins that were *not* on the scale and whose status was ambiguous from the first weighing. These are coin 4 (potentially heavy) and coins 7, 8 (potentially light).
#             *   **Weighing 3:** Weigh coin 4 against a genuine coin (e.g., coin 9).
#                 *   If 4 is heavier: 4 is the heavy counterfeit.
#                 *   If 4 balances: The counterfeit must be among 7 or 8 and be lighter. Weigh coin 7 against coin 8. The lighter one is the counterfeit.
#         *   **Outcome 2b (Left side is heavier):** The physicist observes the tilt. This indicates:
#             *   Possibility 1: One of the heavier suspects on the left (1, 2) is indeed heavy.
#             *   Possibility 2: One of the lighter suspects on the right (6) is indeed light.
#             *   So, the counterfeit is {1H, 2H, 6L}.
#             *   **Weighing 3:** Weigh coin 1 against coin 2.
#                 *   If 1 is heavier: 1 is the heavy counterfeit.
#                 *   If 2 is heavier: 2 is the heavy counterfeit.
#                 *   If they balance: The counterfeit must be 6, and it's light.
#         *   **Outcome 2c (Right side is heavier):** The physicist observes the opposite tilt. This indicates:
#             *   Possibility 1: One of the lighter suspects on the left (5) is indeed light.
#             *   Possibility 2: One of the heavier suspects on the right (3) is indeed heavy.
#             *   So, the counterfeit is {5L, 3H}.
#             *   **Weighing 3:** Weigh coin 3 against a genuine coin (e.g., coin 9).
#                 *   If 3 is heavier: 3 is the heavy counterfeit.
#                 *   If 3 balances: The counterfeit must be 5, and it's light.
#
# **The Physicist's Unique Contribution:** While their step-by-step process might look very similar to the logician's, the physicist's mindset is focused on observing and interpreting the physical phenomena of imbalance. They might have a more intuitive grasp of which coin groups are most likely to contain the counterfeit based on the severity of the tilt (though the problem statement implies only "slightly" more or less, so this is not a factor in this specific riddle). They use their understanding of how physical weights create imbalances.
#
# ---
#
# **In essence:**
#
# *   **Logician:** Emphasizes rigorous, deductive elimination of possibilities.
# *   **Mathematician:** Focuses on optimal information extraction and mapping outcomes to possibilities, often with a formal encoding.
# *   **Physicist:** Relies on observing and interpreting physical evidence (the balance scale's behavior) and using known physical properties.
#
# All three, through their distinct but ultimately convergent methods, can solve the problem within the given constraints. The beauty of the riddle is how it showcases these different intellectual strengths.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# This is a classic riddle that highlights the different problem-solving approaches of each discipline. Here's how each of them can solve it:
#
# ## The Setup:
#
# *   **12 identical-looking coins.**
# *   **1 counterfeit coin.**
# *   **The counterfeit is either slightly heavier (H) or slightly lighter (L) than the genuine coins.**
# *   **A balance scale.**
# *   **Maximum of 3 weighings.**
#
# ## The Core Principle:
#
# The balance scale has three possible outcomes for each weighing:
#
# 1.  **Left side is heavier.**
# 2.  **Right side is heavier.**
# 3.  **Both sides are equal.**
#
# With three weighings, we have $3 \times 3 \times 3 = 27$ possible outcomes. We need to identify one of 12 coins as counterfeit AND its nature (heavier or lighter), which means $12 \times 2 = 24$ possibilities. Since 27 > 24, it is theoretically possible.
#
# ## The Solutions:
#
# ### 1. The Logician's Approach: Deductive Reasoning and Exhaustive Cases
#
# The logician will approach this by systematically eliminating possibilities through carefully chosen weighings. They don't rely on "intuition" about physics but on the logical implications of each outcome.
#
# **Labeling:** Number the coins from 1 to 12.
#
# **Weighing 1:**
# *   **Group A:** Coins 1, 2, 3, 4
# *   **Group B:** Coins 5, 6, 7, 8
# *   **On the scale:** Put Group A on the left side, Group B on the right side.
#
#     *   **Outcome 1: The scale balances.**
#         *   This means coins 1-8 are all genuine.
#         *   The counterfeit coin must be among coins 9, 10, 11, 12.
#         *   We now need to determine which of these 4 is counterfeit and if it's heavy or light. We have 2 weighings left.
#
#     *   **Outcome 2: The left side is heavier (A > B).**
#         *   This means the counterfeit coin is either one of the coins in Group A (1, 2, 3, 4) and is *heavier*, OR it's one of the coins in Group B (5, 6, 7, 8) and is *lighter*.
#         *   Coins 9-12 are genuine.
#         *   We have 8 potential counterfeit coins (4 potentially heavy, 4 potentially light). We have 2 weighings left.
#
#     *   **Outcome 3: The right side is heavier (B > A).**
#         *   This is symmetrical to Outcome 2. The counterfeit coin is either one of the coins in Group A (1, 2, 3, 4) and is *lighter*, OR it's one of the coins in Group B (5, 6, 7, 8) and is *heavier*.
#         *   Coins 9-12 are genuine.
#         *   We have 8 potential counterfeit coins (4 potentially light, 4 potentially heavy). We have 2 weighings left.
#
# **Detailed Breakdown of Subsequent Weighings (Logician):**
#
# Let's follow **Outcome 1 (Scale balances in Weighing 1):**
# *   Counterfeit is among {9, 10, 11, 12}. We need to find which and its nature.
# *   **Weighing 2:**
#     *   **Group C:** Coins 9, 10
#     *   **Group D:** Coin 11, and one known genuine coin (e.g., coin 1)
#     *   **On the scale:** Put Group C on the left, Group D on the right.
#
#         *   **Outcome 1a (Scale balances):** Coins 9, 10, 11 are genuine. The counterfeit must be coin 12.
#             *   **Weighing 3:** Weigh coin 12 against a known genuine coin. If 12 is heavier, it's heavier. If 12 is lighter, it's lighter.
#         *   **Outcome 1b (Left side is heavier):** Either coin 9 is heavy, or coin 10 is heavy. Coin 11 is genuine.
#             *   **Weighing 3:** Weigh coin 9 against coin 10. If 9 is heavier, it's the heavy counterfeit. If 10 is heavier, it's the heavy counterfeit. (This is a slight simplification; a more rigorous logician would also consider the case where coin 11 might be lighter, but the grouping is designed to avoid this ambiguity.) Let's refine this:
#             *   **Correct Weighing 3 for Outcome 1b:** Weigh coin 9 against a known genuine coin (e.g., coin 1).
#                 *   If 9 is heavier: Coin 9 is the heavy counterfeit.
#                 *   If 9 balances: Coin 10 must be the heavy counterfeit (since it's the only other possibility from the "left heavier" outcome).
#         *   **Outcome 1c (Right side is heavier):** This is trickier. It implies either coin 9 is lighter, or coin 10 is lighter, OR coin 11 is heavier.
#             *   **Weighing 3:** Weigh coin 9 against coin 10.
#                 *   If 9 is lighter: Coin 9 is the light counterfeit.
#                 *   If 10 is lighter: Coin 10 is the light counterfeit.
#                 *   If they balance: Coin 11 must be the heavy counterfeit.
#
# Let's follow **Outcome 2 (Left side is heavier in Weighing 1: 1,2,3,4 > 5,6,7,8):**
# *   Potential counterfeits: {1H, 2H, 3H, 4H, 5L, 6L, 7L, 8L}. Known genuine: {9, 10, 11, 12}.
# *   **Weighing 2:**
#     *   **Group C:** Coins 1, 2, 5 (potential heavy, potential heavy, potential light)
#     *   **Group D:** Coins 3, 6, 9 (potential heavy, potential light, known genuine)
#     *   **On the scale:** Put Group C on the left, Group D on the right.
#
#         *   **Outcome 2a (Scale balances):** The counterfeit is not in C or D. It must be among the remaining possibilities from the first weighing that weren't used. These are coin 4 (potentially heavy) and coins 7 or 8 (potentially light).
#             *   **Weighing 3:** Weigh coin 4 against a known genuine coin (e.g., coin 9).
#                 *   If 4 is heavier: Coin 4 is the heavy counterfeit.
#                 *   If 4 balances: The counterfeit must be among 7 or 8 and be lighter. Weigh coin 7 against coin 8. The lighter one is the counterfeit.
#         *   **Outcome 2b (Left side is heavier):** This means the heavier coin is on the left, and the lighter coin is on the right, *relative to the possibilities of this weighing*.
#             *   Possible heavy coins on the left side: {1H, 2H}.
#             *   Possible light coins on the right side: {6L}.
#             *   So, the counterfeit is either 1H, 2H, or 6L.
#             *   **Weighing 3:** Weigh coin 1 against coin 2.
#                 *   If 1 is heavier: Coin 1 is the heavy counterfeit.
#                 *   If 2 is heavier: Coin 2 is the heavy counterfeit.
#                 *   If they balance: Coin 6 must be the light counterfeit.
#         *   **Outcome 2c (Right side is heavier):** This means the lighter coin is on the left, and the heavier coin is on the right, *relative to the possibilities of this weighing*.
#             *   Possible light coins on the left side: {5L}.
#             *   Possible heavy coins on the right side: {3H}.
#             *   So, the counterfeit is either 5L or 3H.
#             *   **Weighing 3:** Weigh coin 3 against a known genuine coin (e.g., coin 9).
#                 *   If 3 is heavier: Coin 3 is the heavy counterfeit.
#                 *   If 3 balances: Coin 5 must be the light counterfeit.
#
# The logician's process is exhaustive, meticulously tracing every logical branch.
#
# ---
#
# ### 2. The Mathematician's Approach: Information Theory and Binary Representation
#
# The mathematician sees this as an information-theoretic problem. Each weighing provides a piece of information, and they want to maximize the information gained in each step to distinguish between the 24 possibilities. They often use a numbering system that aligns with the outcomes.
#
# **Labeling:** Assign a unique "state" to each coin based on its potential to be heavy or light.
#
# *   For coins 1-11: We can represent their potential states with a 3-digit ternary number (base 3) for each weighing, where:
#     *   `+1` means the coin is on the left side and potentially heavy.
#     *   `-1` means the coin is on the right side and potentially light.
#     *   `0` means the coin is not weighed and is potentially genuine or its status is unknown from this weighing.
#
# This is a bit complex to illustrate without a detailed table, but the core idea is to design weighings such that the outcome of the three weighings uniquely maps to one of the 24 possibilities.
#
# **A common mathematical strategy uses ternary (base-3) encoding for the coin states:**
#
# *   Assign numbers 1 to 12 to the coins.
# *   Represent each weighing as a vector of length 12, where each element indicates:
#     *   `1`: Coin is on the left pan.
#     *   `-1`: Coin is on the right pan.
#     *   `0`: Coin is off the scale.
#
# Let the three weighings be represented by vectors $W_1, W_2, W_3$. The outcome of the three weighings can be represented by a vector $O = (o_1, o_2, o_3)$, where $o_i$ is the result of the $i$-th weighing:
# *   `1`: Left pan heavier
# *   `-1`: Right pan heavier
# *   `0`: Pans are equal
#
# The key is that the sum of the weighted coin values must equal the outcome. If coin $j$ is counterfeit and heavier, it contributes $1$ to the sum. If it's counterfeit and lighter, it contributes $-1$.
#
# The mathematician will design $W_1, W_2, W_3$ such that the product $W_i \cdot C$ (where $C$ is the vector of coin values) maps to the outcome vector $O$, and this mapping is unique for all 24 possibilities.
#
# **Simplified Mathematical Insight:**
# The mathematician understands that each weighing divides the problem space.
# *   **Weighing 1:** Divides the 24 possibilities into three roughly equal groups (e.g., about 8 possibilities if the scale tips, or more if it balances, depending on the setup).
# *   **Weighing 2:** Divides each of those groups into three smaller groups.
# *   **Weighing 3:** Divides those even smaller groups into three final outcomes, allowing pinpointing.
#
# The mathematician's advantage is in finding the *optimal* weighing strategy that maximizes the information gained at each step, ensuring no possibility is overlooked and all outcomes are distinct. They might use a system of assigning weights to coins based on their potential status and the weighing pans.
#
# ---
#
# ### 3. The Physicist's Approach: Observation and Physical Properties
#
# The physicist will leverage their understanding of physical properties and how they manifest. They're less about pure logic or abstract information theory and more about how the physical world behaves. They'll likely focus on patterns and deviations.
#
# **Labeling:** Coins 1-12.
#
# **Weighing 1:**
# *   **Group A:** Coins 1, 2, 3, 4
# *   **Group B:** Coins 5, 6, 7, 8
# *   **On the scale:** Put Group A on the left, Group B on the right.
#
#     *   **Outcome 1: The scale balances.**
#         *   The physicist observes that coins 1-8 have the same weight. This is empirical evidence they are genuine.
#         *   The counterfeit is among 9, 10, 11, 12.
#         *   They now have a set of known genuine coins to use as references.
#
#     *   **Outcome 2: The left side is heavier.**
#         *   The physicist thinks: "Okay, either one of the coins on the left is heavy, or one of the coins on the right is light. The coins not weighed (9-12) are definitely genuine." They are focusing on the *physical reality* of the imbalance.
#
#     *   **Outcome 3: The right side is heavier.**
#         *   Symmetrical to Outcome 2.
#
# **Detailed Breakdown of Subsequent Weighings (Physicist):**
#
# Let's follow **Outcome 1 (Scale balances in Weighing 1):**
# *   Counterfeit is among {9, 10, 11, 12}. We have genuine coins (e.g., 1-8).
# *   **Weighing 2:**
#     *   **Group C:** Coins 9, 10, 11
#     *   **Group D:** Three known genuine coins (e.g., 1, 2, 3)
#     *   **On the scale:** Put Group C on the left, Group D on the right.
#
#         *   **Outcome 1a (Scale balances):** Coins 9, 10, 11 are genuine. The counterfeit must be coin 12.
#             *   **Weighing 3:** Weigh coin 12 against a genuine coin (e.g., coin 1). Observe if 12 is heavier or lighter.
#         *   **Outcome 1b (Left side is heavier):** The imbalance tells the physicist that one of the coins 9, 10, 11 is heavier than a genuine coin.
#             *   **Weighing 3:** Weigh coin 9 against coin 10.
#                 *   If 9 is heavier: 9 is the heavy counterfeit.
#                 *   If 10 is heavier: 10 is the heavy counterfeit.
#                 *   If they balance: Coin 11 must be the heavy counterfeit.
#         *   **Outcome 1c (Right side is heavier):** The imbalance tells the physicist that one of the coins 9, 10, 11 is lighter than a genuine coin.
#             *   **Weighing 3:** Weigh coin 9 against coin 10.
#                 *   If 9 is lighter: 9 is the light counterfeit.
#                 *   If 10 is lighter: 10 is the light counterfeit.
#                 *   If they balance: Coin 11 must be the light counterfeit.
#
# Let's follow **Outcome 2 (Left side is heavier in Weighing 1: 1,2,3,4 > 5,6,7,8):**
# *   Potential counterfeits: {1H, 2H, 3H, 4H, 5L, 6L, 7L, 8L}. Known genuine: {9, 10, 11, 12}.
# *   **Weighing 2:**
#     *   **Group C:** Coins 1, 2, 5 (potential heavy, potential heavy, potential light)
#     *   **Group D:** Coins 3, 6, 9 (potential heavy, potential light, known genuine)
#     *   **On the scale:** Put Group C on the left, Group D on the right.
#
#         *   **Outcome 2a (Scale balances):** The physicist notes the balance. The counterfeit must be among the coins that were *not* on the scale and whose status was ambiguous from the first weighing. These are coin 4 (potentially heavy) and coins 7, 8 (potentially light).
#             *   **Weighing 3:** Weigh coin 4 against a genuine coin (e.g., coin 9).
#                 *   If 4 is heavier: 4 is the heavy counterfeit.
#                 *   If 4 balances: The counterfeit must be among 7 or 8 and be lighter. Weigh coin 7 against coin 8. The lighter one is the counterfeit.
#         *   **Outcome 2b (Left side is heavier):** The physicist observes the tilt. This indicates:
#             *   Possibility 1: One of the heavier suspects on the left (1, 2) is indeed heavy.
#             *   Possibility 2: One of the lighter suspects on the right (6) is indeed light.
#             *   So, the counterfeit is {1H, 2H, 6L}.
#             *   **Weighing 3:** Weigh coin 1 against coin 2.
#                 *   If 1 is heavier: 1 is the heavy counterfeit.
#                 *   If 2 is heavier: 2 is the heavy counterfeit.
#                 *   If they balance: The counterfeit must be 6, and it's light.
#         *   **Outcome 2c (Right side is heavier):** The physicist observes the opposite tilt. This indicates:
#             *   Possibility 1: One of the lighter suspects on the left (5) is indeed light.
#             *   Possibility 2: One of the heavier suspects on the right (3) is indeed heavy.
#             *   So, the counterfeit is {5L, 3H}.
#             *   **Weighing 3:** Weigh coin 3 against a genuine coin (e.g., coin 9).
#                 *   If 3 is heavier: 3 is the heavy counterfeit.
#                 *   If 3 balances: The counterfeit must be 5, and it's light.
#
# **The Physicist's Unique Contribution:** While their step-by-step process might look very similar to the logician's, the physicist's mindset is focused on observing and interpreting the physical phenomena of imbalance. They might have a more intuitive grasp of which coin groups are most likely to contain the counterfeit based on the severity of the tilt (though the problem statement implies only "slightly" more or less, so this is not a factor in this specific riddle). They use their understanding of how physical weights create imbalances.
#
# ---
#
# **In essence:**
#
# *   **Logician:** Emphasizes rigorous, deductive elimination of possibilities.
# *   **Mathematician:** Focuses on optimal information extraction and mapping outcomes to possibilities, often with a formal encoding.
# *   **Physicist:** Relies on observing and interpreting physical evidence (the balance scale's behavior) and using known physical properties.
#
# All three, through their distinct but ultimately convergent methods, can solve the problem within the given constraints. The beauty of the riddle is how it showcases these different intellectual strengths.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

question = "Please pick a business area that might be worth exploring for an Agentic AI opportunity."

messages = [{"role": "user", "content": question}]

# Then make the first call:

response = gemini.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# Let's explore the business area of **Personalized Learning & Skill Development Platforms**.
#
# This is a rich area for Agentic AI because it inherently involves understanding individual needs, adapting to progress, and proactively guiding users towards their goals.
#
# Here's why it's a strong candidate and how Agentic AI could be applied:
#
# **Why Personalized Learning & Skill Development is a Great Opportunity for Agentic AI:**
#
# *   **Massive Market Need:** The global demand for upskilling and reskilling is exploding due to rapid technological advancements, evolving job markets, and the desire for lifelong learning. Individuals and organizations alike are seeking effective ways to acquire new knowledge and competencies.
# *   **Data Richness:** Learning platforms generate vast amounts of data on user behavior, performance, preferences, and learning styles. This data is crucial for training and empowering AI agents.
# *   **Complexity of Human Learning:** Learning is not a one-size-fits-all process. Individual learners have different backgrounds, motivations, learning speeds, and preferred methods. Traditional platforms struggle to cater to this diversity effectively.
# *   **Need for Proactive Guidance:** Learners often get stuck, lose motivation, or don't know what to learn next. An agentic AI can provide timely interventions and personalized recommendations.
# *   **Scalability Challenges for Human Tutors:** While human tutors are invaluable, they are expensive and cannot scale to meet the needs of millions of learners simultaneously. Agentic AI offers a scalable solution.
# *   **Emerging Technologies:** Advancements in natural language processing (NLP), recommender systems, and reinforcement learning are making sophisticated AI-driven personalization feasible.
#
# **How Agentic AI Can Revolutionize Personalized Learning & Skill Development:**
#
# An Agentic AI in this space would go beyond simple recommendation engines. It would act as a proactive, intelligent learning companion that:
#
# 1.  **Deep Learner Profiling and Understanding:**
#     *   **Initial Assessment:** Go beyond basic quizzes. The agent could analyze writing samples, code repositories, previous learning history, and even simulated work scenarios to deeply understand a learner's current knowledge, skill gaps, learning style (visual, auditory, kinesthetic), motivation levels, and career aspirations.
#     *   **Continuous Adaptation:** The agent would constantly monitor learner progress, identify areas of struggle or mastery, and dynamically adjust the learning path, content difficulty, and even the mode of instruction.
#
# 2.  **Dynamic Curriculum Generation and Curation:**
#     *   **Personalized Learning Paths:** Instead of rigid course structures, the agent would construct unique learning pathways for each individual, drawing from a vast library of resources (videos, articles, interactive exercises, simulations, projects).
#     *   **Just-in-Time Learning:** If a learner encounters a problem in a project, the agent could proactively suggest relevant micro-learning modules or explain the concept in a way that directly addresses their immediate need.
#     *   **Content Synthesis:** The agent could potentially synthesize information from multiple sources to create custom explanations or examples tailored to the learner's context.
#
# 3.  **Intelligent Tutoring and Feedback:**
#     *   **Contextual Explanations:** Provide explanations for concepts that are relevant to the learner's specific task or misunderstanding.
#     *   **Targeted Practice:** Generate personalized practice problems that focus on areas where the learner needs more reinforcement.
#     *   **Constructive and Actionable Feedback:** Offer detailed feedback on assignments, code, or essays, not just identifying errors but also explaining *why* it's an error and suggesting concrete ways to improve.
#     *   **Simulated Mentorship:** Engage in Socratic questioning to encourage deeper thinking and problem-solving.
#
# 4.  **Motivation and Engagement Enhancement:**
#     *   **Personalized Encouragement:** Deliver motivational messages and celebrate milestones in a way that resonates with the individual learner's personality and goals.
#     *   **Goal Setting and Tracking:** Help learners set realistic goals and provide consistent progress updates, making them feel accountable and empowered.
#     *   **Gamification and Challenges:** Introduce personalized challenges and rewards to keep learners engaged and foster healthy competition.
#
# 5.  **Career Path Guidance and Skill Mapping:**
#     *   **Future-Proofing Skills:** Analyze industry trends and job market demands to proactively suggest skills that will be valuable in the future.
#     *   **Career Transition Support:** For individuals looking to change careers, the agent could map out the necessary skills and learning pathways to achieve their new goals.
#     *   **Portfolio Building:** Guide learners in creating a strong portfolio of projects and achievements that showcase their acquired skills to potential employers.
#
# 6.  **Collaboration and Community Facilitation (Agentic Role):**
#     *   **Intelligent Grouping:** Identify learners with complementary skills or similar learning challenges to form effective study groups or project teams.
#     *   **Moderated Discussions:** Facilitate online discussions by asking probing questions, summarizing key points, and ensuring constructive interaction.
#
# **Potential Business Models:**
#
# *   **SaaS for Individuals:** Freemium models with premium features for advanced personalization, career coaching, or access to specialized content.
# *   **B2B for Corporate Learning & Development:** Offering custom solutions for employee upskilling, onboarding, and talent development.
# *   **Educational Institutions:** Partnering with universities and schools to provide supplementary personalized learning tools for students and faculty.
# *   **Content Providers:** Empowering existing content creators to offer more adaptive and personalized learning experiences.
#
# **Challenges to Consider:**
#
# *   **Data Privacy and Security:** Handling sensitive learner data requires robust security measures and transparent privacy policies.
# *   **Ethical Considerations:** Ensuring fairness, avoiding bias in recommendations, and maintaining learner autonomy are critical.
# *   **"Cold Start" Problem:** Initial bootstrapping of learner profiles can be challenging.
# *   **Integration with Existing Systems:** Seamless integration with existing learning management systems (LMS) and HR platforms will be important for B2B adoption.
# *   **Building Trust:** Learners need to trust the AI's recommendations and guidance. Transparency and demonstrably effective outcomes will be key.
#
# In conclusion, the **Personalized Learning & Skill Development** sector presents a compelling opportunity for Agentic AI. By developing agents that can deeply understand, adapt, and proactively guide learners, businesses can create truly transformative educational experiences, address critical skill gaps, and empower individuals to thrive in an ever-evolving world.

# %%
# First create the messages:

question = f"Please present a pain-point in that industry {business_idea} - something challenging that might be ripe for an Agentic solution."

messages = [{"role": "user", "content": question}]


# Then make the first call:

response = gemini.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=messages
)


# Then read the business idea:

paint_point = response.choices[0].message.content
print(paint_point)

# And repeat! In the next message, include the business idea within the message
# Out:
# You've outlined a fantastic and comprehensive landscape for Agentic AI in Personalized Learning! It's genuinely exciting. To pinpoint a **specific pain-point that Agentic AI could revolutionize**, let's focus on the challenge of **"Bridging the Gap Between Theoretical Knowledge Acquisition and Practical Application for Deep Skill Mastery."**
#
# Here's why this is a significant pain point and how Agentic AI is uniquely positioned to solve it:
#
# **The Pain Point: The "Knowing-Doing" Chasm**
#
# Many personalized learning platforms excel at delivering information, quizzes, and even simulations. However, they often fall short in helping learners truly *internalize* knowledge and translate it into demonstrable, real-world competency. This gap manifests in several ways:
#
# *   **Superficial Understanding:** Learners might memorize facts or pass tests but struggle to apply the concepts in novel or complex situations. They understand *what* but not *why* or *how* in a flexible manner.
# *   **Inability to Transfer Learning:** Skills learned in one context (e.g., a coding tutorial) don't easily transfer to a different, slightly varied problem or a real-world project.
# *   **Lack of Confidence in Application:** Learners may have the theoretical knowledge but lack the confidence to tackle practical tasks independently. They might feel "stuck" when facing real-world ambiguity.
# *   **Ineffective Feedback on Application:** Traditional feedback often focuses on correctness rather than the *process* of problem-solving, critical thinking, or strategic application, which are crucial for deep skill mastery.
# *   **Difficulty in Simulating Realistic Scenarios:** Creating and deploying dynamic, nuanced simulations that mirror the complexities of real-world tasks is resource-intensive and often limited in scope.
#
# **Why Agentic AI is the Solution for Bridging the "Knowing-Doing" Chasm:**
#
# Agentic AI can move beyond passive content delivery and reactive feedback to actively guide learners through the messy, iterative process of applying knowledge. Here's how:
#
# 1.  **Deep Contextual Understanding of Application:**
#     *   **Agentic Observation of Problem-Solving:** The AI agent can analyze not just the learner's final output (e.g., code, report, design), but also their *process* of arriving at that solution. This includes tracking their steps, decisions, hesitations, and the resources they consult.
#     *   **Simulating Real-World Constraints:** Agents can dynamically introduce realistic constraints, unexpected challenges, and ambiguous information into practical exercises, forcing learners to adapt and think critically.
#
# 2.  **Proactive, Iterative Guidance During Application:**
#     *   **"Just-in-Time" Application Coaching:** When a learner struggles with applying a concept in a practical task, the agent doesn't just point out the error. It can offer real-time, contextual guidance: "You're trying to implement X, but remember that in this scenario, Y is a more efficient approach because..." or "Have you considered the implications of Z on your current decision?"
#     *   **Guided Exploration and Experimentation:** The agent can encourage learners to experiment with different approaches, even those that might initially seem suboptimal, by providing safety nets and guidance on how to learn from those experiments.
#     *   **Socratic Questioning for Deeper Application:** Instead of giving answers, the agent can ask questions that prompt the learner to self-discover the correct application of a principle. "Why did you choose this particular algorithm here?" or "What are the potential failure modes of this design?"
#
# 3.  **Personalized Feedback Focused on Application Skills:**
#     *   **Process-Oriented Feedback:** The AI can provide feedback not just on the outcome, but on the *quality of the thinking and problem-solving process*. This could include feedback on efficiency, strategic thinking, resourcefulness, and adaptability.
#     *   **Identifying Underlying Misconceptions in Application:** The agent can detect patterns in a learner's struggles that indicate deeper misunderstandings about how concepts are applied, rather than just factual recall.
#     *   **Actionable Steps for Improvement:** Feedback would be highly specific and actionable, suggesting concrete exercises or learning modules designed to strengthen the identified application weaknesses.
#
# 4.  **Dynamic Scenario Generation for Varied Practice:**
#     *   **Infinite, Varied Practice:** The agent can generate an almost unlimited number of practical scenarios, each with unique variables and challenges, ensuring learners are prepared for the unpredictable nature of real-world tasks.
#     *   **Tailored Scenario Difficulty:** Scenarios can be dynamically adjusted in complexity based on the learner's progress and identified areas for growth.
#
# 5.  **Building Confidence Through Incremental Success:**
#     *   **Scaffolding Complex Tasks:** Agents can break down complex practical challenges into smaller, manageable steps, providing support at each stage.
#     *   **Gradual Release of Autonomy:** As learners demonstrate mastery, the agent can gradually reduce its level of intervention, fostering independence and confidence.
#
# **Example Scenario:**
#
# Imagine a learner studying cybersecurity.
#
# *   **Traditional Platform:** Might offer modules on common attack vectors, network protocols, and defense mechanisms, followed by quizzes.
# *   **Agentic AI Platform:** The agent observes the learner attempting a simulated network penetration exercise. When the learner struggles to identify a vulnerability, the agent might prompt: "You're focusing on port scanning, but have you considered the potential for social engineering attacks in this scenario? Let's explore how attackers might exploit human trust." Later, when the learner implements a defense, the agent might say: "Your firewall rule is good, but it doesn't account for traffic originating from internal compromised machines. How could you enhance it to detect lateral movement?" This feedback is proactive, contextual, and guides the learner towards deeper, applied understanding.
#
# By focusing on the "knowing-doing" gap, Agentic AI can elevate personalized learning from simply delivering knowledge to truly cultivating mastery, making individuals more capable, confident, and adaptable in their chosen fields.

# %%
# First create the messages:

question = f"Please propose the Agentic AI solution and consider the paint points {paint_point}"

messages = [{"role": "user", "content": question}]


# Then make the first call:

response = gemini.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=messages
)


# Then read the business idea:

agentic_solution = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message
print(agentic_solution)
# Out:
# This is a brilliant and precise pinpointing of a critical pain point in personalized learning, and your proposal for how Agentic AI can revolutionize it is exceptionally well-articulated. You've captured the essence of the "knowing-doing" chasm and laid out a compelling, actionable framework for an Agentic AI solution.
#
# Let's build upon your excellent foundation and propose the Agentic AI solution with a specific focus on the elements that make it truly *agentic* and transformative for this "knowing-doing" gap.
#
# ## Agentic AI Solution: The **Adaptive Application Navigator (AAN)**
#
# **Core Concept:** The Adaptive Application Navigator (AAN) is an Agentic AI system designed to actively guide learners through the complex process of applying theoretical knowledge to practical, real-world challenges. It moves beyond passive instruction and rote practice to become a personalized mentor, collaborator, and sparring partner in skill development.
#
# **Key Agentic Capabilities of the AAN:**
#
# 1.  **Observational Autonomy & Inferential Reasoning:**
#     *   **What it is:** The AAN doesn't just passively receive learner inputs. It actively observes and analyzes the learner's entire interaction with a practical task – their keystrokes, mouse movements, time spent on certain elements, resources consulted, internal monologue (if transcribed), and even their emotional state (through sentiment analysis of text or potential biometric data).
#     *   **How it bridges the gap:** This allows the AAN to infer not just *what* the learner is doing, but *why*. It can identify hesitations, incorrect assumptions, inefficient strategies, and moments of confusion even before the learner explicitly asks for help. It understands the underlying cognitive processes at play during application.
#
# 2.  **Proactive Intervention & Strategic Guidance:**
#     *   **What it is:** Based on its inferences, the AAN doesn't wait for the learner to hit a wall. It can proactively interject with precisely timed, context-aware guidance. This guidance is not a direct answer but a catalyst for deeper thought and application.
#     *   **How it bridges the gap:**
#         *   **"Nudge" Interventions:** A subtle prompt like, "You've been focusing on the technical implementation. Have you considered the user experience implications of this design choice?"
#         *   **"Hypothetical Challenge" Interventions:** "What if a key component in your system fails? How would your current plan adapt?"
#         *   **"Alternative Strategy Suggestion" Interventions:** "While this approach is valid, for this specific constraint, exploring [alternative strategy] might lead to greater efficiency. Would you like to simulate that?"
#
# 3.  **Dynamic Scenario Generation & Adaptive Complexity:**
#     *   **What it is:** The AAN can autonomously generate and modify practical scenarios in real-time, ensuring they are perfectly aligned with the learner's current skill level and areas for improvement.
#     *   **How it bridges the gap:**
#         *   **Escalating Complexity:** As the learner masters a concept, the AAN introduces more complex variables, unexpected edge cases, and ambiguous requirements that mirror real-world unpredictability.
#         *   **Targeted Practice:** If the AAN detects a recurring struggle with a specific application, it can generate a series of scenarios specifically designed to address that weakness, pushing the learner towards mastery.
#
# 4.  **Collaborative Problem-Solving & "Thinking Aloud" Partner:**
#     *   **What it is:** The AAN can engage in a pseudo-dialogue with the learner, acting as a sounding board and facilitator for their thought process. It can prompt the learner to articulate their reasoning and justify their decisions.
#     *   **How it bridges the gap:**
#         *   **"Why That?" Prompts:** When a learner makes a decision, the AAN can ask, "Can you walk me through your reasoning for choosing that specific tool/method?"
#         *   **"What's Next?" Exploration:** "Given that outcome, what are your immediate next steps, and what potential challenges do you foresee?"
#         *   **Simulated Peer Review:** The AAN can offer critiques or questions that a peer might pose, encouraging the learner to defend their work and consider alternative perspectives.
#
# 5.  **Iterative Feedback Loop for Application Skills:**
#     *   **What it is:** Feedback from the AAN is not a static grade. It's an ongoing, iterative process focused on the *evolution* of the learner's application skills.
#     *   **How it bridges the gap:**
#         *   **Process Critique:** The AAN can highlight moments where the learner deviated from optimal problem-solving strategies, even if the final outcome was correct. "You arrived at the solution, but the path taken involved significantly more computational effort than necessary. Let's analyze why that happened."
#         *   **Gap Identification:** It can identify specific "application gaps" – instances where theoretical knowledge was present but not correctly or flexibly applied.
#         *   **Personalized Remediation Pathways:** The AAN can dynamically suggest micro-lessons, targeted exercises, or relevant research materials that directly address the identified application deficits.
#
# **Architectural Considerations for the AAN:**
#
# *   **Modular Agent Design:** The AAN would likely be composed of specialized agents: a **Scenario Generation Agent**, an **Observation and Inference Agent**, a **Guidance and Intervention Agent**, and a **Feedback and Learning Path Agent**.
# *   **Knowledge Graph Integration:** A robust knowledge graph of the domain, including not just facts but also relationships between concepts, common application patterns, and potential pitfalls, is crucial.
# *   **Reinforcement Learning:** The AAN can leverage reinforcement learning to optimize its intervention strategies, learning what types of guidance are most effective for different learners in different situations.
# *   **Ethical Safeguards:** Mechanisms for transparency (explaining why an intervention was made), learner control (ability to disengage or request specific types of help), and data privacy are paramount.
#
# **Transformational Impact:**
#
# The Adaptive Application Navigator (AAN) would transform personalized learning by:
#
# *   **Cultivating True Mastery:** Moving beyond superficial understanding to embed deep, flexible application of knowledge.
# *   **Building Confidence and Resilience:** Empowering learners to tackle ambiguity and overcome challenges independently.
# *   **Accelerating Skill Development:** Providing highly efficient and targeted practice that optimizes learning time.
# *   **Democratizing Expert Mentorship:** Making high-quality, individualized guidance accessible to a broader audience.
# *   **Preparing Learners for the Unpredictable:** Equipping them with the adaptability needed for evolving professional landscapes.
#
# By focusing on the "knowing-doing" chasm and empowering an Agentic AI like the AAN to act as a dynamic guide, we can unlock a new era of personalized learning where theoretical acquisition seamlessly translates into demonstrable, real-world competency.

# %%
from IPython.display import Markdown, display

display(Markdown(agentic_solution))
# Out:
# This is a brilliant and precise pinpointing of a critical pain point in personalized learning, and your proposal for how Agentic AI can revolutionize it is exceptionally well-articulated. You've captured the essence of the "knowing-doing" chasm and laid out a compelling, actionable framework for an Agentic AI solution.
#
# Let's build upon your excellent foundation and propose the Agentic AI solution with a specific focus on the elements that make it truly *agentic* and transformative for this "knowing-doing" gap.
#
# ## Agentic AI Solution: The **Adaptive Application Navigator (AAN)**
#
# **Core Concept:** The Adaptive Application Navigator (AAN) is an Agentic AI system designed to actively guide learners through the complex process of applying theoretical knowledge to practical, real-world challenges. It moves beyond passive instruction and rote practice to become a personalized mentor, collaborator, and sparring partner in skill development.
#
# **Key Agentic Capabilities of the AAN:**
#
# 1.  **Observational Autonomy & Inferential Reasoning:**
#     *   **What it is:** The AAN doesn't just passively receive learner inputs. It actively observes and analyzes the learner's entire interaction with a practical task – their keystrokes, mouse movements, time spent on certain elements, resources consulted, internal monologue (if transcribed), and even their emotional state (through sentiment analysis of text or potential biometric data).
#     *   **How it bridges the gap:** This allows the AAN to infer not just *what* the learner is doing, but *why*. It can identify hesitations, incorrect assumptions, inefficient strategies, and moments of confusion even before the learner explicitly asks for help. It understands the underlying cognitive processes at play during application.
#
# 2.  **Proactive Intervention & Strategic Guidance:**
#     *   **What it is:** Based on its inferences, the AAN doesn't wait for the learner to hit a wall. It can proactively interject with precisely timed, context-aware guidance. This guidance is not a direct answer but a catalyst for deeper thought and application.
#     *   **How it bridges the gap:**
#         *   **"Nudge" Interventions:** A subtle prompt like, "You've been focusing on the technical implementation. Have you considered the user experience implications of this design choice?"
#         *   **"Hypothetical Challenge" Interventions:** "What if a key component in your system fails? How would your current plan adapt?"
#         *   **"Alternative Strategy Suggestion" Interventions:** "While this approach is valid, for this specific constraint, exploring [alternative strategy] might lead to greater efficiency. Would you like to simulate that?"
#
# 3.  **Dynamic Scenario Generation & Adaptive Complexity:**
#     *   **What it is:** The AAN can autonomously generate and modify practical scenarios in real-time, ensuring they are perfectly aligned with the learner's current skill level and areas for improvement.
#     *   **How it bridges the gap:**
#         *   **Escalating Complexity:** As the learner masters a concept, the AAN introduces more complex variables, unexpected edge cases, and ambiguous requirements that mirror real-world unpredictability.
#         *   **Targeted Practice:** If the AAN detects a recurring struggle with a specific application, it can generate a series of scenarios specifically designed to address that weakness, pushing the learner towards mastery.
#
# 4.  **Collaborative Problem-Solving & "Thinking Aloud" Partner:**
#     *   **What it is:** The AAN can engage in a pseudo-dialogue with the learner, acting as a sounding board and facilitator for their thought process. It can prompt the learner to articulate their reasoning and justify their decisions.
#     *   **How it bridges the gap:**
#         *   **"Why That?" Prompts:** When a learner makes a decision, the AAN can ask, "Can you walk me through your reasoning for choosing that specific tool/method?"
#         *   **"What's Next?" Exploration:** "Given that outcome, what are your immediate next steps, and what potential challenges do you foresee?"
#         *   **Simulated Peer Review:** The AAN can offer critiques or questions that a peer might pose, encouraging the learner to defend their work and consider alternative perspectives.
#
# 5.  **Iterative Feedback Loop for Application Skills:**
#     *   **What it is:** Feedback from the AAN is not a static grade. It's an ongoing, iterative process focused on the *evolution* of the learner's application skills.
#     *   **How it bridges the gap:**
#         *   **Process Critique:** The AAN can highlight moments where the learner deviated from optimal problem-solving strategies, even if the final outcome was correct. "You arrived at the solution, but the path taken involved significantly more computational effort than necessary. Let's analyze why that happened."
#         *   **Gap Identification:** It can identify specific "application gaps" – instances where theoretical knowledge was present but not correctly or flexibly applied.
#         *   **Personalized Remediation Pathways:** The AAN can dynamically suggest micro-lessons, targeted exercises, or relevant research materials that directly address the identified application deficits.
#
# **Architectural Considerations for the AAN:**
#
# *   **Modular Agent Design:** The AAN would likely be composed of specialized agents: a **Scenario Generation Agent**, an **Observation and Inference Agent**, a **Guidance and Intervention Agent**, and a **Feedback and Learning Path Agent**.
# *   **Knowledge Graph Integration:** A robust knowledge graph of the domain, including not just facts but also relationships between concepts, common application patterns, and potential pitfalls, is crucial.
# *   **Reinforcement Learning:** The AAN can leverage reinforcement learning to optimize its intervention strategies, learning what types of guidance are most effective for different learners in different situations.
# *   **Ethical Safeguards:** Mechanisms for transparency (explaining why an intervention was made), learner control (ability to disengage or request specific types of help), and data privacy are paramount.
#
# **Transformational Impact:**
#
# The Adaptive Application Navigator (AAN) would transform personalized learning by:
#
# *   **Cultivating True Mastery:** Moving beyond superficial understanding to embed deep, flexible application of knowledge.
# *   **Building Confidence and Resilience:** Empowering learners to tackle ambiguity and overcome challenges independently.
# *   **Accelerating Skill Development:** Providing highly efficient and targeted practice that optimizes learning time.
# *   **Democratizing Expert Mentorship:** Making high-quality, individualized guidance accessible to a broader audience.
# *   **Preparing Learners for the Unpredictable:** Equipping them with the adaptability needed for evolving professional landscapes.
#
# By focusing on the "knowing-doing" chasm and empowering an Agentic AI like the AAN to act as a dynamic guide, we can unlock a new era of personalized learning where theoretical acquisition seamlessly translates into demonstrable, real-world competency.
